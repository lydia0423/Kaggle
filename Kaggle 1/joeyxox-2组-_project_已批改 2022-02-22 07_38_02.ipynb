# %% [markdown]
# **声明：**
#
# hello，小伙伴们~
#
# 感谢大家对小鲸鱼的大力支持，目前我在搜集大量经典书籍和资料，其中涉及：
#
# 1. **🔥数学统计：**打好理论基础！
# 2. 🔥**数据分析：**包括数据分析、商业数据分析等
# 3. 🔥**数据科学：**数据建模、机器学习、AI框架等
# 4. 🔥**Python/R cookbook**
#
# 还有关于数据结构、算法、数据库等等
#
# 以及面经、更多的视频资料整理！
#
# 总之，这个仓库会一直更新，分享不会停止！
#
# 不收费，但只分享给有需要的人，曾经没人帮我指路，但我不希望大家走太多弯路！
#
# **公众号：鲸析**
#
# ![](https://s3.bmp.ovh/imgs/2022/02/e213757d6a0c0007.jpg)

# %% [markdown]
# ---
#
# 能够跟大家开启一个Kaggle项目，🐋满怀期待，希望我们能够通力合作，碰撞出火花！
#
# 废话不多说了，首先对整个项目做一个概述，梳理一下分析流程：
#
# **商业意义**
#
# 第一步，本项目的商业意义&目的。
#
# 很明确，目的是预测驾驶员明年提出保险索赔的概率以此控制保险成本。
#
# 原因是老司机不会为高额的保险费而买单，毕竟他们的事故率很低，那么公司通过预测驾驶员明年提出索赔要求的概率来定价。
#
# **问题转化**
#
# 那么结合数据来看，本项目的数据集分为训练集和测试集，训练集共有`595212`行、`59`列，测试集共有`892816`行、`58`列。
#
# > 训练集多出的一列是Target，也就是我们所谓的label，表示该用户是否提出索赔（0 or 1）。
# >
# > 而测试集中没有label，我们需要通过测试集的数据预测其明年的索赔概率，所以并没有用传统的 scoring metric 来进行衡量（confusion matrix等）
#
# 所以我们要对数据进行处理、分析、特征工程，再将处理好的数据代入机器学习模型，最终输出的是概率。
#
# 值得注意的是，项目所给的特征没有标明明确的含义（可能出于对客户的保护），但是给出了对应的变量类型（所以搞清楚变量类型多重要！）
#
# - binary ==> 0 or 1
# - nominal ==> categorical 不含顺序
# - ordinal ==> categorical 含顺序
# - interval ==> continuous 无绝对零点
#
# **项目角色**
#
# 这里不展开，根据个人情况明确项目角色，在这里你就是一个全栈机器学习工程师哈哈哈！
#
# **数据分析**
#
# 这里我给出几个tips，顺着这个思路去思考可能会有帮助！
#
# 1. 数据清洗：缺失值？重复值？异常值？
# 2. 变量类型处理：如何encoding？不同类型变量如何处理？
# 3. 数据可视化：特征分布情况？相关性？
# 4. 特征工程：特征选取？特征增强？特征合并？特征归一化？
#
# **数据建模**
#
# 注意到，我们所处理的是tabular data，也就是表格数据（行列），所以对于这一类数据最好用树模型，比如LightGBM、XGBoost等，不过可以用LR作benchmark。
#
#
# 再给几个tips:
# 1. 如何计算Normalized Gini Coefficient？
# 2. 如何避免过拟合？（kfold/early stopping）
# 3. 如何调参？（max_depth/learning_rate/min_child_weight）
#
#
#
# **测试部署**
#
# 这里主要就是模型的版本迭代、测试并对版本更替进行记录，一般会迭代优化10至20次左右，然后生成submit.csv，并且建议用notebook整合前面所有步骤，并加以文字注解，合并成一份完整文档，并在细节处进行调整。
#
# ---

# %% [markdown]
# [![HaDitA.png](https://s4.ax1x.com/2022/02/11/HaDitA.png)](https://imgtu.com/i/HaDitA)

# %% [markdown]
# ## 项目介绍

# %% [markdown]
# 为了照顾到每位同学的实际情况，我准备把项目劈成2块，上半部分集中于<font color='red'>数据分析</font>，下半部分集中于<font color='red'>数据科学</font>，从而方便各阶段同学更有效地吸收知识，就地取材，在自己的简历上添砖加瓦！
#
# 本笔记（上半部分）旨在深入了解 PorteSeguro 比赛的数据。此外，还提供了一些小tips和tricks来准备数据以备后续的数据建模过程。
#
# ---
#
#
# 该notebook由以下主要部分组成：
#
#
#
# 1. [项目提案&数据梳理](#project_proposal)
#     - 1.1 [项目流程梳理](#progress)
#     - 1.2 [项目提案](#proposal)
#     - 1.3 [数据梳理](#integration)
#
# ---
# 2. [数据分析（一）数据预处理](#data_preprocessing)
# 3. [数据分析（二）探索性分析](#eda)
# 4. [数据分析（三）特征工程](#feat_engineering)
# 5. [数据分析（四）特征选择](#feat_selection)
# 6. [数据建模](#model)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <center><b>项目日志（2022年2月14日）</b></center>
#
# 2022年2月14日情人节，小鲸鱼正式发起第一个kaggle project的挑战，正式开启第一阶段：【项目提案&数据梳理】
#
#
#
# **第一节阶段核心目的：**分析研究项目的核心价值、需求逻辑，建立数据分析框架，并完成项目提案（proposal），以及初步的数据梳理
#
# **难度（最高5星）：**⭐⭐
#
# **第一阶段周期：** 2022年2月14日 至 2022年2月20日（北京时间）
#
#
# **分值**：满分6分，附加题答对8分
#
# Good Luck!
# </div>

# %% [markdown]
# ## 项目提案&数据梳理

# %% [markdown]
# <div class="alert alert-block alert-info">这一次，需要各组长带领各组员分配此次项目的任务以及确定项目角色，并且着重讨论本项目的商业目的。</div>

# %% [markdown]
# 项目团队采用敏捷团队的模式，每个人都尝试成为数据分析师/数据科学家，最后通过能力和完成程度定义自己的角色。

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 1 (2分)</b>: 描述本项目的数据来源，保险公司为什么会发起这次挑战，期待我们解决什么问题？</div>

# %% [markdown]
# <b>成员答案</b>
#
# 1. 杜岩 2/17
# - 较小概率提出理赔的老司机不愿意支持高额保费
#     - 保险公司如果能预测司机理赔的概率就可以降低好司机的保费，提高坏司机的保费，
#     - 公司可以争取到更多好司机客户，提高收益，坏司机保费增加可以增加公司收入抵御理赔风险，也可以变相把一些不想要的坏司机客户拒绝门外
# - 预测用户明年会提出理赔的概率
#
#
# 2. 石刘气泡水 2/18
#
# - Porto Seguro 是一家拥有 75 年市场经验的巴西公司，是巴西最大的保险公司之一，目前拥有近 2000 万客户、1.3 万名员工、1.6 万家供应商和 3.5 万家合作经纪人。该公司还在巴西各地设有 103 个分支机构和地区办事处。
# - Porto Seguro 集团由 27 家公司组成——包括 Azul Seguros 和 Itaú Seguros de Auto e Residência——在保险、金融产品、紧急和便利服务、监控、宠物健康保险等广泛领域开展业务。*该数据来源于Porto Seguro公司的保单持有人的相关数据。*
# - 根据汽车保单持有人的数据建立机器学习模型，分析该持有人是否会在次年提出索赔。通过相关数据分析进行合理定价，在节约成本的同时与持有人购买达到一个平衡，实现最优化。
#
#
# 3. 十二 2/19
#
# - 数据来源：汽车保险公司Porto Seguro提供的公开数据。数据集有原始训练数据集train，59列，595212条，测试数据集有58列，892816条。
# - 原因：有一些好的熟练的司机不怎么会有汽车事故发生，但要支付较高的保险费用。而有些新手或易出现事故的司机保险费用不高，对于好司机来说有些不公平。而且如果新手司机在次年有较多的失误，那么保险公司将支出更多的钱。新的预测模型可以使他们根据这个概率调整价格，使公司获得更多的客户，有更多更盈利的保险单。
# - 期待解决的问题：根据保单持有人的数据建立一个模型，这个模型可以预测驾驶员在次年提出的汽车保险索赔的概率。
#
# 4. Lee yi 2/19
# - 由于受到经济衰退，保险公司在2017年第四季度的净收入为2.696亿巴西雷亚尔，比2016年同时期下降了11.2%。尽管经济衰退已经结束，但保险公司还是受到国家经济危机的影响。在加上巴西有一些州属犯罪率上升，导致汽车保险也间接地受到影响。
# - 所以保险公司发起这次挑战的目的是为了寻找更好的模型来自动预测保险赔偿的概率已经价钱以根据司机的个人情况，为他们打造独一无二的保险以便可以吸引更多的新客户还有留着老顾客。
#
# 5. Luciana 2/19
# - 本次项目数据来源于巴西第三大巴西保险公司Porto Seguro，他们在不同的业务领域拥有约 1000 万客户，市场份额较大，竞争力较强。
# - 虽然 Porto Seguro 过去 20 年来一直使用机器学习，但他们希望 Kaggle 的机器学习社区能够探索新的、更强大的方法。更准确的预测将使他们能够进一步调整价格，并有望使更多司机更容易获得汽车保险。
# - 本次挑战期待我们通过建立更合适的机器学习模型来预测驾驶员在明年提出汽车保险索赔的概率。
#
# 6. Jyy 2/19
# - 通过预测驾驶员是否为好司机的概率来判断该驾驶员提出索赔的可能性，进而对该司机的保险单进行定价，
# - 通过进行合理定价，达到降低成本及减少好司机的保单流失的目的
#
# 7. shto 2/19
# - 数据来自该保险公司，公司希望我们构建一个车主申请保险报销的概率模型来更合理地根据车主情况给车险定价，以获得更多客户和更高利润。

# %% [markdown]
# <b>汇总</b>
#
# 1.项目背景
#
# - <b>政治</b>：
#     - 2017年4月，巴西政府发布了2018年起实施的新汽车政策《Rota 2030》，旨在完善投资环境和提高国内汽车行业竞争力。[来源](https://www.marklines.com/cn/report_all/rep1628_201708#report_area_4)
#     - 巴西法律要求所有司机都要有汽车保险，至少包括第三方责任保险，即免受第三方死亡或身体伤害的潜在责任。[来源](https://calculator8.com/br/car-insurance/#:~:text=Car%20insurance%2C%20which%20comes%20under%20vehicle%20insurance%20policy%2C,to%20accident%2C%20theft%20or%20loss%20of%20the%20car.)
#         - 车险种类包括：
#             - *第三方责任保险*：巴西法律规定每个人都必须购买此保单。它提供了对被保险汽车对第三方和财产造成的任何损害所引起的责任的保障。
#             - *共同乘客保护范围*：一些保险提供商为共同乘客提供人身事故保险。如果乘客或驾驶人死亡，可以获得100%的赔偿。如果乘客或驾驶人永久性残疾，可以要求100%的赔偿。
#             - *个人风险保障*：保单通常只为车主提供保障。但是，除了驾驶员之外，任何其他持有有效执照的人也可以通过购买人身伤害保险附加险来获得保障。
#             - *综合保单*：这是一项全包计划，为与汽车、第一方、同乘人员和第三方相关的所有风险提供端到端的保障。它还涵盖所有自然灾害或人为灾难，包括地震、山体滑坡、洪水、罢工和骚乱。
#         - 综合保单投保最多，2018年占据了接近70%的投保额；其次是第三方责任保险，2018年占据了22%。[来源](https://www.casact.org/sites/default/files/presentation/spring_2019_presentations_c-7_ortega.pdf)
# - <b>经济</b>：
#     - 2015-2016年，巴西受到经济衰退的影响，呈现连续两年负增长。2017年，巴西经济呈缓慢复苏态势，新车销售和生产都有所增长。[来源](https://www.marklines.com/cn/report_all/rep1628_201708#report_area_2)
#     - 2017年，车险业务渗透率几乎保持稳定，但仍需扩大新客户的保险渠道。[来源](https://seekingalpha.com/article/4144606-porto-seguro-sa-ord-2017-q4-results-earnings-call-slides)
#         - 车险的行业集中度比较高，top5的公司占了60%的保险费，其中包括Porto Seguro。 [来源](https://www.casact.org/sites/default/files/presentation/spring_2019_presentations_c-7_ortega.pdf)
#         - 2017年第一季度，各大保险公司竞争激烈。第二季度竞争减少，但是呈现增长的公司同时呈现更高的花费。[来源](https://seekingalpha.com/article/4144606-porto-seguro-sa-ord-2017-q4-results-earnings-call-slides)
# - <b>社会</b>:
#     - 由于车险承担能力不足和政府执法不力的问题，许多汽车还没有购买保险。2018年仅有23%的的汽车涵盖保险。[来源](https://www.expatbriefing.com/country/brazil/financial/insurance-for-expats-in-brazil.html)
#         - 车险每年所需费用通常在汽车总价格的3%到10%之间。车险根据车主的年龄、汽车的使用方式、驾驶人数以及汽车本身的不同而有很大差异。[来源](https://thebrazilbusiness.com/article/costs-of-owning-a-car-in-brazil)
#         - 受经济的影响，巴西有一些州属犯罪率上升，保险公司不得不考虑潜在的风险给出更高的定价。
#     - 巴西互联网和智能手机普及程度较高，超过2/3的巴西人接触到智能手机和网络，他们每天花费超过9个小时在网络上。但不同地区、不同社会地位和不同年龄层的网速和普及程度不一样。
# - <b>技术</b>:
#     - 各大公司研究保险产品电子化，希望通过app向人们投放产品
#
# 2. 项目对象
# - Porto Seguro 是一家拥有 75 年市场经验的巴西公司，是巴西最大的保险公司之一，目前拥有近 2000 万客户、1.3 万名员工、1.6 万家供应商和 3.5 万家合作经纪人。该公司还在巴西各地设有 103 个分支机构和地区办事处。
# - Porto Seguro 集团由 27 家公司组成——包括 Azul Seguros 和 Itaú Seguros de Auto e Residência——在保险、金融产品、紧急和便利服务、监控、宠物健康保险等广泛领域开展业务。
#
# 3. 项目目的
# - 2017年，巴西经济复苏，新车销售额增加，购买车险的潜在客户增加。但是第一季度车险行业竞争激烈，第二季度得到增长的公司无不需要花费更高的费用。而增加市场渗透率同时控制成本的关键，在于一个更为精确的模型，能够预估一个驾驶员需要理赔的概率，从而给出更加合理的定价。
# - 因为目前车险行业的定价对于大部分消费者来说无法承担，对于好的、熟练的司机来说，他们不经常发生交通事故，过高的保险费会流失这部分用户；而对于新手、易出现事故的司机来说，过低的保险费会使保险公司的成本增加。
# - 更加精细化的客户管理也是需要的，对于已经购买车险的客户，应该分析其特征，推荐更为匹配的保险产品。
#
# 4. 数据来源
# - 本项目用到的数据是由Porto Seguro保险公司2017年发布在Kaggle平台上的公开数据集，包括训练集和测试集。
# - 训练集共有595212行、59列，测试集共有892816行、58列。
# - 训练集多出的一列是Target，表示该用户是否提出索赔（0 or 1）。

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 2 (2分)</b>: 根据项目要求，简要叙述关于本项目，你们组希望从哪些方面解决问题（所解决的问题继承上一题的答案）</div>

# %% [markdown]
# 1. 杜岩 2/17
# - 数据清洗 缺失值、异常值、归一化
# - 探索性分析 查看特征相关性，特征选择
#
# 2. 石刘气泡水 2/18
# - 进行数据特征的整理。
# - 数据清洗：去缺失值，处理重复值，处理异常值。
# - 变量类型处理：对多分类变量进行哑变量处理。
# - 探索性分析数据可视化：分布比例，变量之间相关性。
# - 特征工程：特征选取，降维处理，归一化。
# - 进行数据建模，得出模型计算方法，合理预测，准确度判断。
#
# 3. 十二 2/19
# - 数据分析：
#     - 预处理：查看数剧是否有缺失值，处理缺失值；查看数据是否有异常值；理解列名的含义，对数据列的数据类型和特征名称进行归类，获取数据信息。
#     - 探索性分析：训练集中的target列进行分析；对数据求相关，查看列之间的关系；进行可视化。
#     - 特征分析：分别对二分类特征（后缀为bin的列），多分类特征（后缀为cat）的取值分布；分析无后缀的列，区分出连续变量和顺序变量，进行分析；这些特征与target列的关系；选取有重要性特征，筛选特征。
# - 数据建模：建立模型并训练，预测结果，输出驾驶员在次年可能索赔的概率。
#
# 4. Lee yi 2/19
# - 我们组希望所建立的模型可以根据司机的个人情况，比如婚姻情况，收入，驾驶经历已经交通事故等来预测保险的价钱。
#
# 5. Luciana 2/19
# - 由于Porto Seguro汽车保险业务的索赔预测不准确提高了好司机的保险成本，降低坏司机的支付费用，从而同时影响公司汽车业务的收益和用户体验，所以需要更精确的预测模型来提高收益。
# - 从活动目的出发，我们组希望解决建立更准确的模型来预测驾驶员在明年提出汽车保险索赔的概率，从而提高Porto Seguro汽车保险业务的收益，通过建立数据分析框架，特征工程，数据建模和测试部署来优化预测模型，最终为Porto Seguro汽车保险业务提出合适的定价策略。
#
# 6. Jyy 2/19
# - 主要考虑从数据清洗方面和模型选择两方面来解决问题，因为一个坏司机造成的损失极大可能远大于一个好司机带来的收益，所以尽量在保证好司机的预测准确性的前提下提高坏司机的预测准确性
#
# 7. shto 2/19
# - 项目需要分析车主各项指标和发生事故的可能性之间的联系构建一个概率模型，对进行潜在客户发生事故的概率进行预测，从而合理定价。对发生事故概率小的车主给出较低报价以吸引更多客户，给发生事故概率高的车主相应地提高报价，以保证利润。建模可通过分析数据各项指标进行。

# %% [markdown]
# <b>汇总</b>
#
# - 项目目的：
#     - 分析已经购买车险的驾驶人的特征，划分为不同的消费群体，有利于未来做进一步的产品推荐
#     - 建立模型且训练，得到驾驶人次年索赔的概率
#         - 在特征筛选方面增加维度
#         - 在指标方面，以降低FN（错误地把一个坏司机当成一个好司机）为主要目的
#
# - 框架：主要分为两部分，数据分析和数据建模。
#     - 数据分析：
#         - 预处理：处理缺失值、重复值、异常值；处理数据不均衡；理解列名的含义。
#         - 探索性分析：
#             - 对数据求相关，查看列之间的关系；
#             - 对二分类特征（后缀为bin的列）、多分类特征（后缀为cat）的取值分布；
#             - 通过可视化寻找一些结论
#         - 特征分析：
#             - 分析无后缀的列，区分出连续变量和顺序变量；
#             - target列与其他特征列的关系；
#             - 对多分类变量进行哑变量处理；
#             - 归一化。
#         - 特征选择
#     - 数据建模

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 3 (1分)</b>: 在接触实际数据之前，我们对项目有了初步的认识，那么我们来看看实际的数据吧！请使用pandas的read_csv函数导入项目数据（train和test）</div>

# %%
# 代码写在下面
import pandas as pd
import os
path = os.getcwd()
train_data = pd.read_csv(path + '/data/train.csv')
test_data = pd.read_csv(path + '/data/test.csv')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <p style="font-size:20px; display:inline">💡</p> 小贴士：
#
# pd.read_csv的参数使用：<br>
#     <font color = #0abfab>在notebook中，点击函数，按住【Shift+Tab】，可以查看函数使用方法</font><br>
# <center><font color = #fc5430 size = 3>header</font></center>
# 默认值为0，意为将文件第0行数据作为列名；<br>
# 若header=None，则自动生成0，1，2，...为列名，文件从第0行就读取为数据；<br>
# 若header=1，则第0行被舍弃，第1行读取为列名；<br>
# <center><font color = #fc5430 size = 3>index_col</font></center>
#     默认是None，若表中没有索引，不需设置，如果自带索引（第0列），那么需要设置 index_col = 0
# <center><font color = #fc5430 size = 3>skiprows</font></center>
#     跳过某些行，例如 skiprows=lambda x: x % 2 != 0
# <center><font color = #fc5430 size = 3>nrows</font></center>
#     nrows=20 则读取20行，从第0行开始读
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 4 (1分)</b>: 尝试用 info(), head(), tail() 函数检查训练数据和测试数据</div>

# %% [markdown]
# 以下是比赛数据的基本描述：
#
# 由于对于客户安全性的考虑，特征名称没用明确给出。
#
# * 属于**相似分类的特征在特征名称中被标记为**（例如，ind、reg、car、calc）。
# * 特征名称包括表示二元特征的后缀 **bin**（0 or 1） 和表示分类特征的 **cat**。
# * 特征**没有这些名称是连续的或有序的**。
# * **-1** 的值表示该特征在观察中**缺失**。
# * **target** 列表示是否为该保单持有人提出索赔。
#
# 让我们快速用代码查看数据的基本情况吧！

# %%
# TODO: info() 检查特征名字、非空值以及变量类型
train_data.info()
#test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              595212 non-null  int64
#  1   target          595212 non-null  int64
#  2   ps_ind_01       595212 non-null  int64
#  3   ps_ind_02_cat   595212 non-null  int64
#  4   ps_ind_03       595212 non-null  int64
#  5   ps_ind_04_cat   595212 non-null  int64
#  6   ps_ind_05_cat   595212 non-null  int64
#  7   ps_ind_06_bin   595212 non-null  int64
#  8   ps_ind_07_bin   595212 non-null  int64
#  9   ps_ind_08_bin   595212 non-null  int64
#  10  ps_ind_09_bin   595212 non-null  int64
#  11  ps_ind_10_bin   595212 non-null  int64
#  12  ps_ind_11_bin   595212 non-null  int64
#  13  ps_ind_12_bin   595212 non-null  int64
#  14  ps_ind_13_bin   595212 non-null  int64
#  15  ps_ind_14       595212 non-null  int64
#  16  ps_ind_15       595212 non-null  int64
# ...

# %%
# TODO: head() 查看前10行
train_data.head(10)
#test_data.head(10)
# Out:
#    id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0   7       0          2              2          5              1
# 1   9       0          1              1          7              0
# 2  13       0          5              4          9              1
# 3  16       0          0              1          2              0
# 4  17       0          0              2          0              1
# 5  19       0          5              1          4              0
# 6  20       0          2              1          3              1
# 7  22       0          5              1          4              0
# 8  26       0          5              1          3              1
# 9  28       1          1              1          2              0
#
#    ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# 0              0              0              1              0  ...
# 1              0              0              0              1  ...
# ...

# %%
# TODO: tail() 查看后7行
train_data.tail(7)
#test_data.tail(7)
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 595205  1488009       0          0              3          6              1
# 595206  1488011       0          0              1          2              0
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# 595205              0              0              1              0  ...
# 595206              0              0              0              0  ...
# 595207              0              0              0              0  ...
# ...

# %% [markdown]
# 👊<font color=red>附加挑战（2分）</font>
#
# 因为我们常常要上面的方法去检查数据，有一个基本的理解，那么我们想一下子看到数据的前五行和后五行，合并在一起。
#
#
# ---
#
#
# **请编写一个函数，名为`check_data`，输入为dataframe，输出为一个新dataframe，满足一下条件：**
#
#
# 1. 一共10行，列数为输入dataframe的列数
# 2. 前5行是输入dataframe的前五行，后5行是输入dataframe的后五行

# %%
# 你的答案
def check_data(dataset):
    return pd.concat([dataset.head(5), dataset.tail(5)],axis=0)

# %%
check_data(train_data)
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0             7       0          2              2          5              1
# 1             9       0          1              1          7              0
# 2            13       0          5              4          9              1
# 3            16       0          0              1          2              0
# 4            17       0          0              2          0              1
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# ...

# %% [markdown]
# **补充：**
#
# 如果你有余力，建议从下面链接中完成这100道Python Pandas puzzle！来为你下一阶段保驾护航！
#
# 链接：https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles.ipynb

# %% [markdown]
# ## 总结
#
# 2组做的太棒了，完全符合我的预期和要求，包含了各个组员的contribution，并且实现汇总，内容部分也是无法挑剔！
#
# 是所有组里面，我最满意的！所以项目满分是8分，我给10分！A+
#
# pandas附加题及时改正了！
#
# 13/11 Congrats!👍👍👍

# %% [markdown]
# [![H65i3d.gif](https://s4.ax1x.com/2022/02/14/H65i3d.gif)](https://imgtu.com/i/H65i3d)

# %% [markdown]
# <img src="https://s4.ax1x.com/2022/02/14/H65vxs.jpg" alt="image-20220214212808413" style="zoom:25%;" />
